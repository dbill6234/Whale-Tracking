# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import csv

# %%
data = np.genfromtxt('C:\users\dbill\Desktop\_train.csv', delimiter = ',', skip_header = 1)
print (data.shape)
# Out:
# (30000L, 3L)

# %% [markdown]
# # Note:  Graph truncated to 500 to make more readible.

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = [20,5]
plt.plot(data[0:500,1], data[0:500,2])
plt.title ('Whale Tracking')
plt.xlabel ('Sample')
plt.ylabel ('Whale Detected')
# Out:
# Text(0,0.5,'Whale Detected')

# %% [markdown]
# # Using the entire data set of 30,000 makes graph unreadible

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = [20,5]
plt.plot(data[:,1], data[:,2])
plt.title ('Whale Tracking')
plt.xlabel ('Sample')
plt.ylabel ('Whale Detected')
# Out:
# Text(0,0.5,'Whale Detected')
